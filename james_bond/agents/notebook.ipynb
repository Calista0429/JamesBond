# %%
from dotenv import load_dotenv
from hello_agents import HelloAgentsLLM, ToolRegistry
from hello_agents.tools import CalculatorTool
from simple_agent import MySimpleAgent

# 加载环境变量
load_dotenv("../../.env")

# 创建LLM实例
llm = HelloAgentsLLM()

# 测试1:基础对话Agent（无工具）
print("=== 测试1:基础对话 ===")
basic_agent = MySimpleAgent(
    name="基础助手",
    llm=llm,
    system_prompt="你是一个友好的AI助手，请用简洁明了的方式回答问题。"
)

response1 = basic_agent.run("你好，请介绍一下自己是什么模型")
print(f"基础对话响应: {response1}\n")
# Out:
# === 测试1:基础对话 ===
# ✅ 基础助手 初始化完成，工具调用: 禁用
# 🤖 基础助手 正在处理: 你好，请介绍一下自己是什么模型
# ✅ 基础助手 响应完成
# 基础对话响应: 你好！我是 DeepSeek，由深度求索公司创造的 AI 助手。
#
# 我目前是 DeepSeek 最新版本模型，知识截止日期到 2025 年 5 月。我的主要特点包括：
#
# - **纯文本模型**，支持阅读链接
# - **免费使用**，无需付费
# - **支持文件上传**（图片、PDF、Word、Excel 等），可以从中提取文字信息
# - **上下文长度 1M**，可以一次性处理像《三体》三部曲那样的大体量书籍
# - **支持联网搜索**（需要手动开启）
# - **App 端支持语音输入**
#
# 有什么我可以帮你的吗？😊

# %%
# 测试2:带工具的Agent
print("=== 测试2:工具增强对话 ===")
tool_registry = ToolRegistry()
calculator = CalculatorTool()
tool_registry.register_tool(calculator)

enhanced_agent = MySimpleAgent(
    name="增强助手",
    llm=llm,
    system_prompt="你是一个智能助手，可以使用工具来帮助用户。",
    tool_registry=tool_registry,
    enable_tool_calling=True
)

response2 = enhanced_agent.run("请帮我计算 15 * 8 + 32")
print(f"工具增强响应: {response2}\n")
# Out:
# === 测试2:工具增强对话 ===
# ✅ 工具 'python_calculator' 已注册。
# ✅ 增强助手 初始化完成，工具调用: 启用
# 🤖 增强助手 正在处理: 请帮我计算 15 * 8 + 32
# 🔧 检测到 1 个工具调用
# 🧮 正在计算: 15 * 8 + 32
# ✅ 计算结果: 152
# ✅ 增强助手 响应完成
# 工具增强响应: 计算结果为：15 × 8 + 32 = 120 + 32 = 152。

# %%
# 测试3:流式响应
print("=== 测试3:流式响应 ===")
print("流式响应: ", end="")
for chunk in basic_agent.stream_run("请解释什么是人工智能"):
    pass  # 内容已在stream_run中实时打印
# Out:
# === 测试3:流式响应 ===
# 流式响应: 🌊 基础助手 开始流式处理: 请解释什么是人工智能
# 📝 实时响应: 🧠 正在调用 deepseek-v4-pro 模型...
# ✅ 大语言模型响应成功:
# 人工智能人工智能（（AIAI））简单简单来说来说，，就是就是****让让机器机器像像人人一样一样思考思考、、学习和学习和解决问题的能力解决问题的能力****。
#
# 。
#
# 它它通过通过计算机计算机程序程序来来模拟模拟人类的人类的感知感知、、推理推理、、决策决策等等智能智能行为行为。。根据根据能力能力范围范围，，通常通常分为分为：
#
# ：
#
# -- ** **弱弱人工智能人工智能****：：专注于专注于特定特定任务任务，，如如人脸人脸识别识别、、语音语音助手助手、、推荐推荐算法算法等等。。当前当前所有所有 AI AI  都属于都属于这一类这一类。
# 。
# -- ** **强强人工智能人工智能****：：具备具备通用通用智能智能，，能能像像人类人类一样一样理解理解并并解决解决各种各种问题问题，，目前目前还未还未实现实现。
#
# 。
#
# AIAI  的核心的核心实现实现方式方式包括包括****机器学习机器学习****和和****深度学习深度学习****：：用用大量大量数据数据训练训练模型模型，，让让模型模型自动自动寻找寻找规律规律，，而不是而不是预先预先设定设定好好所有所有规则规则。。比如比如你你让让 AI AI  识别识别猫猫的的图片图片，，不是不是告诉告诉它它““猫猫有有圆圆脸脸、、尖尖耳朵耳朵”，”，而是而是给它给它看成看成千千上万上万张张猫猫图图，，它它自己自己总结总结出出猫猫的特征的特征。
#
# 。
#
# 希望希望这个这个解释解释对对你有你有帮助帮助！！
#
# ✅ 基础助手 流式响应完成

# %%
# 测试4:动态添加工具
print("\n=== 测试4:动态工具管理 ===")
print(f"添加工具前: {basic_agent.has_tools()}")
basic_agent.add_tool(calculator)
print(f"添加工具后: {basic_agent.has_tools()}")
print(f"可用工具: {basic_agent.list_tools()}")

# 查看对话历史
print(f"\n对话历史: {len(basic_agent.get_history())} 条消息")
